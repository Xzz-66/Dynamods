# %%
# Imports
import numpy as np

# Probability matices
# Emmision probabilities [a u g c] [E I].T
emission = np.array([[0.25, 0.25, 0.25, 0.25],
                     [0.4, 0.4, 0.05, 0.15]])

# Transition probabilities [E I] [E, I].T
transition = np.array([[0.9, 0.1],
                       [0.2, 0.8]])

# Initial state probablities [E I]
initial = [0.5, 0.5]

# 'agcgc'
patient_alpha = [0,2,3,2,3]
# 'auuau'
patient_beta = [0,1,1,0,1]

def recursion(previous_delta, transition, emission, observation):
    
    psi = []
    delta = []
    for s in range(2):
        
        lst = [previous_delta[r] * transition[r, s] * emission[s, observation] for r in range(2)]
        
        arg_max = np.argmax(lst)
        max = np.max(arg_max)
        
        psi.append(arg_max)
        delta.append(max)
        
    return delta, psi 

def init_delta(initial, emission, observation):
    return [initial[s] * emission[s, observation] for s in range(2)]

def termination(delta, psi):

    psi = np.array(psi)

    state = psi[np.argmax(delta), -1]
    final_state_path = [state]
    
    for i in range(psi.shape[0]-1, 0, -1):
        state = psi[i, state]
        final_state_path.append(state.copy())
    
    return final_state_path

def viterbi(initial, emission, transition, observation):
    
    # Initialization
    delta = init_delta(initial, emission, observation[0])
    
    # Recursion
    backtrack = []
    for o in observation[1:]:
        delta, psi = recursion(delta, transition, emission, o)
        backtrack.append(psi)
        
    # Termination
    final_state_path = termination(delta, backtrack)
    
    return final_state_path

alpha_state_path = viterbi(initial, emission, transition, patient_alpha)
beta_state_path = viterbi(initial, emission, transition, patient_beta)

print(alpha_state_path)
print(beta_state_path)
# Out:
# [np.int64(1), np.int64(1), np.int64(1), np.int64(1)]
# [np.int64(1), np.int64(1), np.int64(1), np.int64(1)]

# %%
class Viterbi():
    def __init__(self, init_prob, trans_prob, emis_prob):
        
        self.init_prob = init_prob      # Initial probabilities [E, I]
        self.trans_prob = trans_prob    # Transition probabilities [E, I] [E, I].T
        self.emis_prob = emis_prob      # Emmision probabilities [a u g c] [E I].T
        
    def run_viterbi(self, observation):
        '''
        Help
        '''
        
        def init_delta(observation): 
            '''
            Initialize the recursion by computing delta for t=1 following the euqaiton cap_pi(s)*B(O_{0}|s).
            '''
            return [self.init_prob[s] * self.emis_prob[s, observation] for s in range(2)]
    
        def recursion(previous_delta, observation):
            '''
            Help
            '''
            # Initialise lists to store psi and delta
            psi = []
            delta = []
            
            # Repeat for amount of states (E, I)
            for s in range(2):
                
                # Compute delta_{t-1}(r) * A(r|s) * B(O_{t}|s) for r = (0, 1)
                state_prob = [previous_delta[r] * self.trans_prob[r, s] * self.emis_prob[s, observation] for r in range(2)]
                
                arg_max = np.argmax(state_prob) # Get index of max
                max = state_prob[arg_max]       # Get probability of max
                
                psi.append(arg_max)
                delta.append(max)
                
            return delta, psi 

        def termination(delta, psi):
            '''
            Help
            '''
            print(psi)
            # Get the state of the last 
            state = psi[-1, np.argmax(delta)]
            
            final_state_path = [state]
            for i in range(psi.shape[0]-1, 0, -1):
                state = psi[i, state]
                final_state_path.append(state.copy())
            
            return final_state_path
        
        # Initialization
        delta = init_delta(observation=observation[0])
        
        # Recursion
        backtrack = np.zeros((len(observation), 2), dtype=int)
        for t, o in enumerate(observation[1:]):
            delta, psi = recursion(delta, o)
            backtrack[t,:] = psi
    
        # Termination
        final_state_path = termination(delta, backtrack)
        
        return final_state_path

# %%
# Probability matices
# Emmision probabilities [a u g c] [E I].T
emission = np.array([[0.25, 0.25, 0.25, 0.25],
                     [0.4, 0.4, 0.05, 0.15]])

# Transition probabilities [E I] [E, I].T
transition = np.array([[0.9, 0.1],
                       [0.2, 0.8]])

# Initial state probablities [E I]
initial = [0.5, 0.5]

# 'agcgc'
patient_alpha = [0,2,3,2,3]
# 'auuau'
patient_beta = [0,1,1,0,1]

model = Viterbi(initial, transition, emission)

print(model.run_viterbi(observation=patient_alpha))
# print(model.run_viterbi(model, patient_beta))
# Out:
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[39], line 20
#      16 patient_beta = [0,1,1,0,1]
#      18 model = Viterbi(initial, transition, emission)
# ---> 20 print(model.run_viterbi(observation=patient_alpha))
#      21 # print(model.run_viterbi(model, patient_beta))
#
# Cell In[38], line 66, in Viterbi.run_viterbi(self, observation)
#      63     np.append(backtrack, psi)
#      65 # Termination
# ---> 66 final_state_path = termination(delta, backtrack)
#      68 return final_state_path
#
# Cell In[38], line 47, in Viterbi.run_viterbi.<locals>.termination(delta, psi)
#      45 print(psi)
#      46 # Get the state of the last
# ---> 47 state = psi[-1, np.argmax(delta)]
#      49 final_state_path = [state]
#      50 for i in range(psi.shape[0]-1, 0, -1):
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
